# %% [markdown]
# ### Slide 1
# Graduated from University of Illinois at Chicago
# Worked for Northwestern University
# Research interest:
# Distributed Machine Learning
# Deep Learning
# Bioinformatics
# …
# This is Keren Li, Ph.D
# Department of Mathematics - College of Arts and Sciences
# A figure generated by ChatGPT
